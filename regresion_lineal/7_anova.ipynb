# %% [markdown]
# # Pair Programming ANOVA
#
# En el pair programming de hoy usaremos el set de datos que guardastéis en el pair programming de normalización y estandarización.
#
# En el ejercicio de hoy tendréis que hacer un ANOVA con vuestro datos y hacer una interpretación de los resultados.
#
# 📌 NOTA Puede que vuestros datos no se ajusten o no cumplan todas las asunciones, no pasa nada, haced el ANOVA e interpretad los resultados. En próximas lecciones aprenderemos que podemos hacer cuando nos encontramos en esta situación.

# %%
# Tratamiento de datos
# -----------------------------------------------------------------------
import numpy as np
import pandas as pd
import random 

# Gráficos
# ------------------------------------------------------------------------------
import matplotlib.pyplot as plt
import seaborn as sns

# Estadísticos
# ------------------------------------------------------------------------------
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.multivariate.manova import MANOVA
from sklearn.preprocessing import StandardScaler

plt.rcParams["figure.figsize"] = (10,8)

# %%
df = pd.read_csv('../archivos/coste_vida_limpio.csv', index_col = 0)
df.head()
# Out:
#         city      country  Meal_Inexpensive_Restaurant
# 0      Seoul  South Korea                         7.68  \
# 1   Shanghai        China                         5.69
# 2  Guangzhou        China                         4.13
# 3     Mumbai        India                         3.68
# 4      Delhi        India                         4.91
#
#    Mealfor2_Midrange_Restaurant  McMeal_at_McDonalds  Cappuccino  Milk  Rice
# 0                         53.78                 6.15        3.93  2.20  3.53  \
# 1                         39.86                 5.69        3.98  2.74  1.22
# 2                         28.47                 4.98        3.54  1.91  1.03
# 3                         18.42                 3.68        2.48  0.75  0.83
# 4                         22.11                 4.30        1.77  0.73  0.85
#
#    Eggs_12uds  Chicken_Fillets  ...  Primary_School_Yearly  Apt_1bed_inCentre
# 0        4.04            10.58  ...               17902.55             742.54  \
# ...

# %%
len(df['city'].unique())
# Out:
# 4898

# %%
df.shape
# Out:
# (4956, 36)

# %%
df.columns
# Out:
# Index(['city', 'country', 'Meal_Inexpensive_Restaurant',
#        'Mealfor2_Midrange_Restaurant', 'McMeal_at_McDonalds', 'Cappuccino',
#        'Milk', 'Rice', 'Eggs_12uds', 'Chicken_Fillets', 'Beef_Round',
#        'Water_market', 'Wine_market', 'Domestic_Beer', 'Imported_Beer',
#        'Cigarettes_Marlboro', 'One_way_TicketTransport',
#        'Monthly_Pass_Regular_Price', 'Taxi', 'Gasoline', 'Basic',
#        'Prepaid_Mobile', 'Internet', 'Gym_Monthly', 'Cinema',
#        'Preschool_Monthly', 'Primary_School_Yearly', 'Apt_1bed_inCentre',
#        'Apt_1bed_OutsideCentre', 'Apt_3beds_inCentre',
#        'Apt_3beds_OutsideCentre', 'Price_per_Square_Meter_inCentre',
#        'Price_per_Square_Meter_OutsideCentre', 'Average_Monthly_Net_Salary',
#        'Mortgage_Interest_Rate', 'data_quality'],
#       dtype='object')

# %%
lm = ols('Basic ~ country + Meal_Inexpensive_Restaurant + Mealfor2_Midrange_Restaurant + McMeal_at_McDonalds + Cappuccino + Milk + Rice + Eggs_12uds + Chicken_Fillets + Beef_Round + Water_market + Wine_market + Domestic_Beer + Imported_Beer + Cigarettes_Marlboro + One_way_TicketTransport + Monthly_Pass_Regular_Price + Taxi + Gasoline + Prepaid_Mobile + Internet + Gym_Monthly + Cinema + Preschool_Monthly + Primary_School_Yearly + Apt_1bed_inCentre + Apt_1bed_OutsideCentre + Apt_3beds_inCentre + Apt_3beds_OutsideCentre + Price_per_Square_Meter_inCentre + Price_per_Square_Meter_OutsideCentre + Average_Monthly_Net_Salary + Mortgage_Interest_Rate + data_quality', data=df).fit()
sm.stats.anova_lm(lm)
# Out:
#                                           df        sum_sq        mean_sq
# country                                214.0  2.104825e+07   98356.309148  \
# Meal_Inexpensive_Restaurant              1.0  2.590407e+05  259040.688945
# Mealfor2_Midrange_Restaurant             1.0  1.718078e+05  171807.825171
# McMeal_at_McDonalds                      1.0  3.008849e+04   30088.492742
# Cappuccino                               1.0  5.326974e+04   53269.739644
# Milk                                     1.0  6.143329e+03    6143.328792
# Rice                                     1.0  4.040405e+04   40404.052285
# Eggs_12uds                               1.0  8.699678e+04   86996.780600
# Chicken_Fillets                          1.0  3.026181e+04   30261.809229
# Beef_Round                               1.0  3.190699e+04   31906.986356
# Water_market                             1.0  1.044580e+03    1044.579607
# Wine_market                              1.0  4.107294e+02     410.729368
# ...
