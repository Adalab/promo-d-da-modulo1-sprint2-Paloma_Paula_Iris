# %% [markdown]
# ## Asunciones Regresión Lineal

# %% [markdown]
# En este ejercicio de pair programming seguiréis usando el dataset que seleccionasteis.
#
# El objetivo de este pairprgramming es que evaluéis si vuestro set de datos cumple todas las asunciones que se deben cumplir para hacer una regresión lineal. Recordamos que estas asunciones son:

# %% [markdown]
# >Cada asunción la deberéis testar de forma visual y analítica.

# %%
import numpy as np
import pandas as pd
import random 

import matplotlib.pyplot as plt
import seaborn as sns
import sidetable as stb

from scipy import stats
import researchpy as rp
from scipy.stats import levene
from scipy.stats import kstest

plt.rcParams["figure.figsize"] = (10,8) 
pd.options.display.max_columns = None

# %%
df = pd.read_csv('../archivos/coste_vida_valido.csv', index_col = 0)

# %%
df.sample(3)
# Out:
#             city      country  mcdonalds  cappuccino  milk  rice     eggs  \
# 3545  Greifswald      Germany      10.00        5.12  1.59  7.72  5.00000
# 4018     Veendam  Netherlands       7.50        1.89  1.03  1.61  2.64724
# 145       Anshan        China       3.07        1.57  0.68  0.71  1.03000
#
#         chicken   beef  banana  water   wine  beer  cigarettes_marlboro  \
# 3545  14.330000  17.09    3.38   2.38  12.00  1.79                11.00
# 4018   9.779307  15.34    1.08   1.50  12.00  3.57                 7.50
# 145    3.480000   6.52    0.58   0.35   6.14  1.81                 4.05
#
#       public_transport_ticket      taxi  gasoline   basic  internet  \
# 3545                 2.750000  2.019915   1.40000  290.00     54.67
# 4018                 2.132023  1.410430   1.58409  274.48     75.00
# 145                  0.430000  0.150000   1.25000   47.83      8.66
#
#       gym_monthly  cinema    preschool  primary_school  apt_3beds_outcentre  \
# 3545    64.726474   12.00  1434.265349    18000.000000              4000.00
# 4018    12.000000   10.00   615.788798     9788.124628              1000.00
# 145     19.960000    3.68    51.340000     1271.160000               180.13
#
#       monthly_salary
# 3545     6500.000000
# 4018     2193.234392
# 145       569.740000

# %%
list(df['basic'].unique())
# Out:
# [182.13,
#  66.0,
#  59.65,
#  43.57,
#  58.07,
#  37.06,
#  128.77,
#  83.88,
#  67.63,
#  553.99,
#  79.55,
#  66.56,
#  26.53,
#  69.27,
#  48.85,
#  28.27,
#  31.81,
#  55.64,
#  145.92,
#  171.22,
#  98.89,
#  180.61,
#  68.88,
#  48.19,
#  24.93,
#  92.43,
#  33.92,
#  36.49,
#  299.36,
#  40.46,
#  28.69,
#  21.1,
#  199.44,
#  206.04,
#  74.15,
#  140.05,
#  36.3,
#  71.32,
#  93.12,
#  76.64,
#  67.77,
#  52.99,
#  30.78,
#  45.79,
#  163.78,
#  74.36,
#  45.92,
#  42.69,
#  39.47,
#  25.46,
#  49.82,
#  92.53,
#  53.62,
#  56.41,
#  67.58,
#  53.07,
#  89.91,
#  42.81,
#  199.78,
#  92.87,
#  38.07,
#  59.83,
#  138.18,
#  48.49,
#  35.59,
#  48.9,
#  92.83,
#  39.99,
#  156.11,
#  37.01,
#  47.45,
#  123.31,
#  34.2,
#  166.08,
#  41.59,
#  34.17,
#  32.39,
#  170.42,
#  41.97,
#  63.46,
#  84.52,
#  166.22,
#  28.18,
#  71.18,
#  173.45,
#  213.22,
#  53.86,
#  64.83,
#  127.96,
#  145.68,
#  159.71,
#  131.53,
#  49.32,
#  38.09,
#  21.56,
#  70.83,
#  42.71,
#  185.0,
#  133.25,
#  72.6,
#  170.85,
#  148.65,
#  37.98,
#  36.92,
#  21.35,
#  56.94,
#  106.1,
#  31.99,
#  209.47,
#  75.22,
#  13.51,
#  43.6,
#  181.61,
#  221.73,
#  104.88,
#  308.3,
#  46.76,
#  48.36,
#  141.08,
#  37.97,
#  280.06,
#  80.09,
#  47.83,
#  54.03,
#  43.91,
#  201.77,
#  84.57,
#  32.61,
#  143.33,
#  168.33,
#  43.98,
#  131.06,
#  201.62,
#  47.04,
#  73.31,
#  34.32,
#  168.49,
#  76.54,
#  197.83,
#  88.2,
#  158.16,
#  93.68,
#  53.18,
#  58.6,
#  86.06,
#  91.44,
#  42.16,
#  78.3,
#  82.34,
#  28.47,
#  44.9,
#  132.48,
#  86.9,
#  23.64,
#  57.56,
#  192.01,
#  42.75,
#  79.17,
#  80.59,
#  96.39,
#  73.63,
#  17.46,
#  143.1,
#  56.8,
#  26.75,
#  91.96,
#  198.35,
#  91.93,
#  54.84,
#  56.93,
#  88.24,
#  50.18,
#  37.14,
#  50.23,
#  42.32,
#  60.67,
#  35.16,
#  123.0,
#  68.33,
#  41.65,
#  148.18,
#  246.39,
#  187.27,
#  32.32,
#  206.66,
#  14.29,
#  41.9,
#  142.85,
#  24.64,
#  49.02,
#  59.37,
#  12.37,
#  249.17,
#  32.47,
#  27.98,
#  111.69,
#  267.24,
#  25.62,
#  33.01,
#  47.17,
#  39.42,
#  216.55,
#  261.38,
#  20.0,
#  38.95,
#  64.4,
#  56.04,
#  118.89,
#  287.14,
#  165.59,
#  29.22,
#  90.69,
#  22.82,
#  97.0,
#  280.0,
#  16.31,
#  18.48,
#  207.8,
#  198.99,
#  140.69,
#  31.79,
#  191.73,
#  200.44,
#  154.04,
#  199.46,
#  31.01,
#  156.47,
#  77.53,
#  128.62,
#  52.24,
#  55.0,
#  152.13,
#  72.98,
#  61.09,
#  155.19,
#  40.19,
#  107.1,
#  225.27,
#  15.76,
#  204.69,
#  64.46,
#  28.99,
#  33.93,
#  30.71,
#  42.47,
#  204.48,
#  49.46,
#  54.34,
#  149.11,
#  151.77,
#  15.0,
#  22.51,
#  32.41,
#  97.78,
#  93.4,
#  302.81,
#  120.47,
#  131.48,
#  110.97,
#  109.17,
#  104.25,
#  121.0,
#  148.74,
#  50.71,
#  89.02,
#  132.51,
#  67.18,
#  63.85,
#  100.34,
#  19.51,
#  26.44,
#  200.67,
#  152.57,
#  42.99,
#  216.3,
#  57.63,
#  149.77,
#  51.2,
#  267.29,
#  62.11,
#  138.75,
#  33.53,
#  69.13,
#  161.35,
#  210.07,
#  54.75,
#  77.14,
#  29.48,
#  134.2,
#  165.33,
#  102.68,
#  31.52,
#  149.08,
#  21.49,
#  189.53,
#  32.83,
#  135.07,
#  140.58,
#  33.75,
#  18.42,
#  27.18,
#  77.9,
#  50.11,
#  34.3,
#  121.51,
#  148.94,
#  139.05,
#  89.34,
#  126.82,
#  106.24,
#  16.0,
#  69.31,
#  103.26,
#  49.76,
#  64.82,
#  45.03,
#  219.9,
#  99.66,
#  18.26,
#  72.91,
#  29.08,
#  122.75,
#  74.47,
#  32.12,
#  26.48,
#  32.64,
#  203.32,
#  25.79,
#  99.44,
#  117.1,
#  279.73,
#  240.96,
#  190.35,
#  153.72,
#  21.53,
#  184.3,
#  82.24,
#  189.4,
#  57.03,
#  45.61,
#  101.31,
#  136.5,
#  51.92,
#  105.78,
#  26.28,
#  44.52,
#  97.34,
#  116.99,
#  73.44,
#  188.64,
#  94.26,
#  71.05,
#  68.97,
#  66.44,
#  86.07,
#  16.28,
#  77.87,
#  374.83,
#  19.35,
#  74.72,
#  216.1,
#  82.57,
#  194.69,
#  195.88,
#  30.7,
#  100.0,
#  48.6,
#  71.93,
#  119.98,
#  37.96,
#  16.13,
#  102.95,
#  154.97,
#  95.0,
#  201.27,
#  23.56,
#  53.55,
#  31.26,
#  95.97,
#  281.94,
#  30.0,
#  130.42,
#  145.32,
#  113.79,
#  107.09,
#  108.82,
#  98.85,
#  265.12,
#  244.58,
#  24.6,
#  134.82,
#  145.96,
#  96.59,
#  18.43,
#  37.51,
#  304.7,
#  133.62,
#  205.18,
#  234.35,
#  305.91,
#  53.69,
#  130.77,
#  278.36,
#  321.92,
#  92.68,
#  152.05,
#  219.17,
#  140.5,
#  147.67,
#  138.14,
#  97.44,
#  16.06,
#  92.44,
#  164.68,
#  59.86,
#  261.63,
#  253.55,
#  62.73,
#  157.04,
#  75.45,
#  112.5,
#  21.69,
#  159.57,
#  92.78,
#  46.85,
#  108.5,
#  107.05,
#  80.1,
#  101.86,
#  169.42,
#  192.0,
#  204.87,
#  108.71,
#  46.59,
#  191.33,
#  301.9,
#  101.82,
#  47.86,
#  211.78,
#  51.0,
#  57.06,
#  40.68,
#  6.07,
#  184.18,
#  34.04,
#  92.19,
#  196.17,
#  189.67,
#  68.08,
#  285.2,
#  271.65,
#  55.74,
#  135.51,
#  190.43,
#  556.06,
#  83.58,
#  224.76,
#  212.63,
#  1066.67,
#  533.33,
#  79.75,
#  111.01,
#  54.27,
#  67.51,
#  158.99,
#  177.76,
#  129.51,
#  76.19,
#  46.25,
#  200.0,
#  194.84,
#  128.28,
#  68.7,
#  84.18,
#  81.62,
#  196.8,
#  283.33,
#  271.83,
#  250.0,
#  225.0,
#  76.88,
#  149.59,
#  245.23,
#  29.02,
#  103.17,
#  235.41,
#  40.29,
#  41.22,
#  75.94,
#  39.37,
#  10.11,
#  58.96,
#  59.39,
#  177.81,
#  210.95,
#  45.91,
#  103.15,
#  212.5,
#  63.55,
#  13.48,
#  135.98,
#  54.68,
#  79.93,
#  108.25,
#  241.89,
#  132.02,
#  51.57,
#  190.84,
#  144.61,
#  55.27,
#  37.99,
#  38.1,
#  151.71,
#  43.75,
#  60.0,
#  58.82,
#  111.91,
#  235.15,
#  49.15,
#  18.01,
#  11.26,
#  98.88,
#  193.29,
#  47.9,
#  98.4,
#  282.08,
#  27.02,
#  48.12,
#  58.73,
#  59.09,
#  294.14,
#  141.51,
#  84.05,
#  152.21,
#  341.76,
#  16.38,
#  52.86,
#  150.0,
#  40.23,
#  20.88,
#  228.11,
#  28.15,
#  113.04,
#  58.91,
#  42.83,
#  84.77,
#  100.12,
#  145.8,
#  146.65,
#  125.29,
#  49.34,
#  213.78,
#  58.79,
#  136.81,
#  84.61,
#  106.04,
#  186.13,
#  37.76,
#  280.82,
#  150.75,
#  129.18,
#  65.97,
#  54.28,
#  38.91,
#  13.21,
#  19.45,
#  76.25,
#  44.86,
#  155.17,
#  193.54,
#  57.49,
#  18.8,
#  81.37,
#  202.73,
#  21.36,
#  31.69,
#  220.3,
#  46.88,
#  53.29,
#  231.09,
#  25.49,
#  80.03,
#  174.48,
#  25.38,
#  50.55,
#  22.35,
#  69.58,
#  65.62,
#  217.42,
#  56.16,
#  158.33,
#  208.17,
#  115.23,
#  43.82,
#  18.1,
#  225.33,
#  239.55,
#  121.47,
#  171.66,
#  237.34,
#  97.51,
#  119.68,
#  100.07,
#  14.4,
#  24.5,
#  225.34,
#  84.76,
#  190.71,
#  50.0,
#  152.74,
#  22.11,
#  108.28,
#  48.61,
#  143.54,
#  151.93,
#  180.32,
#  49.38,
#  69.21,
#  72.07,
#  118.29,
#  127.38,
#  69.41,
#  117.13,
#  45.7,
#  38.24,
#  36.85,
#  54.46,
#  238.91,
#  145.62,
#  159.18,
#  238.29,
#  28.66,
#  57.17,
#  94.93,
#  297.52,
#  143.7,
#  193.04,
#  48.88,
#  237.28,
#  233.34,
#  151.61,
#  312.5,
#  33.98,
#  95.8,
#  121.81,
#  128.41,
#  101.87,
#  119.99,
#  58.34,
#  261.88,
#  222.28,
#  233.75,
#  78.13,
#  134.22,
#  93.53,
#  162.37,
#  188.61,
#  123.13,
#  44.67,
#  255.46,
#  56.5,
#  84.62,
#  120.33,
#  26.63,
#  75.42,
#  209.39,
#  98.68,
#  32.5,
#  231.32,
#  82.77,
#  12.28,
#  130.41,
#  62.49,
#  208.83,
#  120.86,
#  28.68,
#  184.48,
#  61.82,
#  33.62,
#  233.67,
#  177.33,
#  98.44,
#  214.48,
#  25.58,
#  236.07,
#  168.08,
#  223.36,
#  29.55,
#  14.74,
#  87.14,
#  10.0,
#  116.73,
#  45.0,
#  214.92,
#  76.16,
#  316.42,
#  233.15,
#  95.24,
#  51.95,
#  87.18,
#  45.73,
#  55.44,
#  386.53,
#  46.35,
#  17.74,
#  101.15,
#  208.12,
#  326.37,
#  205.54,
#  128.05,
#  189.57,
#  276.5,
#  98.87,
#  41.86,
#  166.81,
#  24.56,
#  81.2,
#  24.51,
#  17.88,
#  202.13,
#  27.75,
#  225.75,
#  161.45,
#  138.15,
#  96.86,
#  213.58,
#  76.55,
#  129.19,
#  33.42,
#  114.38,
#  120.61,
#  33.77,
#  172.92,
#  135.92,
#  297.81,
#  268.54,
#  162.23,
#  29.05,
#  20.35,
#  117.83,
#  83.21,
#  41.26,
#  155.07,
#  63.19,
#  34.78,
#  108.57,
#  250.12,
#  224.22,
#  45.37,
#  157.18,
#  52.2,
#  204.3,
#  299.18,
#  120.73,
#  60.83,
#  77.43,
#  139.56,
#  83.35,
#  135.87,
#  42.58,
#  176.43,
#  79.52,
#  137.29,
#  87.28,
#  56.27,
#  221.81,
#  101.67,
#  39.29,
#  123.26,
#  53.79,
#  85.42,
#  178.08,
#  155.5,
#  64.0,
#  21.37,
#  33.25,
#  148.98,
#  104.23,
#  202.49,
#  180.24,
#  64.93,
#  76.41,
#  184.66,
#  66.98,
#  98.92,
#  73.01,
#  229.79,
#  200.74,
#  128.12,
#  227.08,
#  111.66,
#  31.16,
#  43.13,
#  236.71,
#  185.51,
#  218.64,
#  296.31,
#  179.42,
#  156.84,
#  129.73,
#  160.06,
#  332.5,
#  134.19,
#  78.73,
#  53.22,
#  59.21,
#  97.23,
#  33.57,
#  92.24,
#  87.5,
#  81.06,
#  214.76,
#  96.11,
#  102.02,
#  312.04,
#  17.68,
#  44.07,
#  62.64,
#  175.02,
#  34.19,
#  114.8,
#  132.5,
#  42.51,
#  91.38,
#  132.04,
#  59.6,
#  59.32,
#  31.3,
#  84.9,
#  43.22,
#  211.9,
#  141.81,
#  153.19,
#  115.7,
#  292.96,
#  30.11,
#  73.49,
#  340.06,
#  257.57,
#  193.98,
#  178.27,
#  57.48,
#  22.52,
#  325.01,
#  28.74,
#  165.27,
#  149.22,
#  20.47,
#  136.92,
#  146.8,
#  58.53,
#  138.82,
#  304.66,
#  35.88,
#  284.99,
#  73.06,
#  39.61,
#  46.41,
#  218.75,
#  247.74,
#  126.3,
#  144.72,
#  91.05,
#  96.09,
#  29.9,
#  62.01,
#  76.82,
#  122.27,
#  53.83,
#  43.43,
#  125.45,
#  27.63,
#  176.18,
#  46.22,
#  88.75,
#  55.56,
#  39.08,
#  38.32,
#  43.83,
#  147.6,
#  182.5,
#  178.52,
#  138.3,
#  135.18,
#  34.63,
#  158.94,
#  130.61,
#  110.72,
#  169.21,
#  90.71,
#  175.57,
#  267.98,
#  40.91,
#  23.38,
#  138.0,
#  38.56,
#  261.69,
#  91.24,
#  274.63,
#  152.26,
#  104.56,
#  237.95,
#  177.37,
#  153.27,
#  146.61,
#  161.96,
#  104.66,
#  46.01,
#  68.72,
#  156.41,
#  208.16,
#  27.24,
#  229.47,
#  139.01,
#  25.78,
#  30.91,
#  80.5,
#  155.58,
#  114.51,
#  62.45,
#  239.46,
#  113.34,
#  144.86,
#  41.46,
#  94.12,
#  91.5,
#  178.18,
#  98.97,
#  29.61,
#  125.52,
#  114.73,
#  138.44,
#  96.9,
#  249.88,
#  55.35,
#  51.84,
#  95.59,
#  127.5,
#  100.38,
#  174.49,
#  98.32,
#  187.26,
#  253.44,
#  36.07,
#  39.39,
#  157.63,
#  238.65,
#  46.06,
#  191.14,
#  22.0,
#  257.47,
#  24.61,
#  213.16,
#  134.3,
#  125.0,
#  40.53,
#  58.74,
#  60.11,
#  131.68,
#  288.75,
#  31.33,
#  176.5,
#  71.77,
#  106.56,
#  200.9,
#  43.04,
#  246.75,
#  113.91,
#  24.52,
#  228.13,
#  283.15,
#  147.09,
#  88.18,
#  149.29,
#  68.27,
#  76.35,
#  187.2,
#  194.9,
#  258.8,
#  25.51,
#  110.73,
#  133.83,
#  30.48,
#  72.29,
#  48.43,
#  68.8,
#  59.56,
#  102.4,
#  56.43,
#  166.53,
#  78.66,
#  30.12,
#  98.13,
#  72.2,
#  79.81,
#  215.14,
#  267.9,
#  158.05,
#  104.69,
#  198.46,
#  ...]

# %%
df['basic'].isnull().sum()
# Out:
# 0

# %%
df['basic'].describe()
# Out:
# count    4081.000000
# mean      135.718165
# std        85.441646
# min         6.070000
# 25%        67.960000
# 50%       127.500000
# 75%       184.480000
# max      1066.670000
# Name: basic, dtype: float64

# %%
sns.boxplot(df['basic'])
plt.savefig('vr_no_normal.png');
# Out:
# /home/adalaber/Descargas/anaconda/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['basic'].isnull().sum()
# Out:
# 0

# %%
df['basic'].dtypes
# Out:
# dtype('float64')

# %%
df.shape
# Out:
# (4081, 25)

# %% [markdown]
# 1- Normalidad (ya la deberíais haber evaluado)

# %%
sns.histplot(df['basic']);

# %%
stats.shapiro(df["basic"])
# Out:
# ShapiroResult(statistic=0.9131569862365723, pvalue=2.1159606811304738e-43)

# %% [markdown]
# Buscamos una variable que sí cumpla con el criterio de normalidad hasta que aprendamos a normalizar los datos.

# %%
numericas = df.select_dtypes(include=np.number)

# %%
for col in numericas.columns:
    print(f'{col} = {stats.shapiro(numericas[col])[1]}')
# Out:
# mcdonalds = 3.4838724543004026e-29
# cappuccino = 8.958853588520797e-30
# milk = 0.0
# rice = 0.0
# eggs = 6.608482079321293e-38
# chicken = 0.0
# beef = 0.0
# banana = 0.0
# water = 0.0
# wine = 6.483023267290907e-40
# beer = 9.509071249061776e-41
# cigarettes_marlboro = 0.0
# public_transport_ticket = 0.0
# taxi = 1.0709563643448847e-39
# gasoline = 9.793950713047217e-25
# basic = 2.1159606811304738e-43
# internet = 0.0
# gym_monthly = 0.0
# cinema = 2.476649800063862e-30
# preschool = 0.0
# primary_school = 0.0
# apt_3beds_outcentre = 0.0
# monthly_salary = 0.0

# %% [markdown]
# No tenemos ninguna variable numércia que cumpla con la normalidad.

# %% [markdown]
# 2- Homogeneidad de varianzas

# %%
len(numericas.columns)
# Out:
# 23

# %%
for i, colum in enumerate(numericas.columns): 
    print(i, colum)
# Out:
# 0 mcdonalds
# 1 cappuccino
# 2 milk
# 3 rice
# 4 eggs
# 5 chicken
# 6 beef
# 7 banana
# 8 water
# 9 wine
# 10 beer
# 11 cigarettes_marlboro
# 12 public_transport_ticket
# 13 taxi
# 14 gasoline
# 15 basic
# 16 internet
# 17 gym_monthly
# 18 cinema
# 19 preschool
# 20 primary_school
# 21 apt_3beds_outcentre
# 22 monthly_salary

# %%
fig, axes = plt.subplots(12,2, figsize = (30, 70))
axes = axes.flat

columnas_numeric = numericas.columns

for i, colum in enumerate(columnas_numeric): 
    sns.regplot(
        data = numericas,
        x = colum,
        y = 'basic',
        #color = lista_colores[i],
        line_kws = {"color": "black", "alpha": 0.7 }, 
        ax = axes[i])
    
plt.savefig('regplot_num.png');

# %%
resultados = {}

# seleccionamos solo las columnas numéricas y eliminamos la columna de precio
numericas_col = df.select_dtypes(include = np.number).drop("basic", axis = 1).columns

#iteremos por la lista de las columnas numéricas
for col in numericas.columns:
    # calculamos el p-valor de test
    statistic, p_val = levene(numericas[col], numericas.basic, center='median')
    # lo almacenamos en el diccionario
    resultados[col] = p_val

# %%
resultados
# Out:
# {'mcdonalds': 0.0,
#  'cappuccino': 0.0,
#  'milk': 0.0,
#  'rice': 0.0,
#  'eggs': 0.0,
#  'chicken': 0.0,
#  'beef': 1.7271333279182074e-150,
#  'banana': 0.0,
#  'water': 0.0,
#  'wine': 0.0,
#  'beer': 0.0,
#  'cigarettes_marlboro': 0.0,
#  'public_transport_ticket': 0.0,
#  'taxi': 0.0,
#  'gasoline': 0.0,
#  'basic': 1.0,
#  'internet': 0.5125802995465959,
#  'gym_monthly': 0.0,
#  'cinema': 0.0,
#  'preschool': 0.0,
#  'primary_school': 0.0,
#  'apt_3beds_outcentre': 0.0,
#  'monthly_salary': 0.0}

# %% [markdown]
# 3- Independencia de las variables

# %% [markdown]
# Hemos estado observando la independencia a lo largo de los jupyter. Si queremos hacer regresión lineal habrá que eliminar alguna variable.

# %%
mask = np.triu(np.ones_like(numericas.corr(),dtype = np.bool_))

# %%
plt.figure(figsize= (15,15))

sns.heatmap(numericas.corr(),
            cmap = 'coolwarm',
            annot = True,
            mask = mask,
            vmin = -1,
            vmax= 1);
